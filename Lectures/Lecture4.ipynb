# %% [markdown]
# # CEE 690-02
#
# # Environmental Spatial Data Analysis
#
# # Lecture 4

# %% [markdown]
# ## Review + Today
#
# * General overview of Python
# * Introduction to Numpy
# * Introduction to plotting in Python

# %% [markdown]
# ## Moving forward
#
# * After we complete the introductory background in Python today, we will slow down.
# * However, the rest of the course will require to develop and mantain an intermediate level of understanding of all the we have covered until now.
# * In other words, **you have been warned**.

# %% [markdown]
#  # Logistics (I)
#
# * Homeworks submitted after they are due at the beginning of class on Tuesdays will no longer be accepted.
# * Problems with using git pull at the beginning of class? Read the email I sent out on Tuesday evening.
# * Solutions to the first homework are on Sakai.
# * Start thinking about your groups for the projects. If they are not assembled by 09/17, I will randomly assign them!

# %% [markdown]
# ## Logistics (II)
# * Each group for the final project should have 4 members.
# * Tomorrow is the last day to drop. You know what this course involves now!
# * Starting next Thursday, groups of 3 will review the previous week's homework.
# * I am going to randomly draw next week's group after we review last week's homework.

# %% [markdown]
# ![image.png](https://matplotlib.org/_static/logo2.png)

# %% [markdown]
# The following Matplotlib lecture is adapted from the Scipy lecture notes (https://scipy-lectures.org/) and the official Matplolib tutorials (https://matplotlib.org/tutorials). For more information, I encourage you to check out these resources.

# %% [markdown]
# Matplotlib is the primary tool for exploratory and publication-quality graphs in Python. Becoming experts in Numpy + Matplotlib will take you far.

# %% [markdown]
# ## Getting started

# %% [markdown]
# When running matplotlib in a Jupyter notebook, we use cell magic to tell matplotlib to show the created figures within the notebook.

# %%
# %matplotlib inline

# %% [markdown]
# Within `matplotlib`, `pyplot` is the module that is most commonly used to make graphs. It has a `Matlab`-feel to it.

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Plotting with default settings

# %%
x = np.linspace(-2*np.pi, 2*np.pi, 100)
y1 = np.cos(x)
y2 = np.sin(x)
plt.plot(x,y1)
plt.plot(x,y2)
plt.show()

# %% [markdown]
# ## Changing colors, line widths, and line styles

# %%
plt.plot(x, y1, color="blue", linewidth=2.5, linestyle="-")
plt.plot(x, y2, color="green",  linewidth=5, linestyle="--")
plt.show()

# %% [markdown]
# ## Setting limits

# %%
plt.plot(x, y1, color="blue", linewidth=2.5, linestyle="-")
plt.plot(x, y2, color="red",  linewidth=2.5, linestyle="--")
plt.xlim([-10,10])
plt.ylim([-2,2])
plt.show()

# %% [markdown]
# ## Setting ticks

# %%
plt.plot(x, y1, color="blue", linewidth=2.5, linestyle="-")
plt.plot(x, y2, color="red",  linewidth=2.5, linestyle="--")
plt.xlim([-5,5]);plt.ylim([-2,2])
plt.xticks([-np.pi,0,np.pi])
plt.yticks([-1,-0.5,0,0.5,1])
plt.show()

# %% [markdown]
# ## Setting tick labels

# %%
plt.plot(x, y1, color="blue", linewidth=2.5, linestyle="-")
plt.plot(x, y2, color="red",  linewidth=2.5, linestyle="--")
plt.xlim([-5,5]);plt.ylim([-1.5,1.5])
plt.xticks([-np.pi,0,np.pi],[r'$-\pi$',0,r'$\pi$'],fontsize=20) #Latex inside of pyplot
plt.yticks([-1,-0.5,0,0.5,1],fontsize=15)
plt.show()

# %% [markdown]
# ## Moving spines

# %%
plt.plot(x, y1, color="blue", linewidth=2.5, linestyle="-")
plt.plot(x, y2, color="red",  linewidth=2.5, linestyle="--")
plt.xlim([-5,5]);plt.ylim([-1.5,1.5])
plt.xticks([-np.pi,0,np.pi],[r'-$\pi$',0,r'$\pi$'],fontsize=20) #Latex inside of pyplot
plt.yticks([-1,-0.5,0,0.5,1],fontsize=15)
ax = plt.gca()  # gca stands for 'get current axis'
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.spines['bottom'].set_position(('data',0))
ax.spines['left'].set_position(('data',0))
plt.show()

# %% [markdown]
# ## Adding a legend

# %%
plt.xlim([-5,5]);plt.ylim([-1.5,1.5])
plt.xticks([-np.pi,0,np.pi],[r'-$\pi$',0,r'$\pi$'],fontsize=20) #Latex inside of pyplot
plt.yticks([-1,-0.5,0,0.5,1],fontsize=15)
ax = plt.gca()  # gca stands for 'get current axis'
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.spines['bottom'].set_position(('data',0))
ax.spines['left'].set_position(('data',0))
plt.plot(x, y1, color="blue", linewidth=2.5, linestyle="-")
plt.plot(x, y2, color="red",  linewidth=2.5, linestyle="--")
plt.legend([r'$\cos$','sin'],fontsize=10)
plt.show()

# %% [markdown]
# ## Saving plot (I)

# %%
plt.plot(x, y1, color="blue", linewidth=2.5, linestyle="-")
plt.plot(x, y2, color="red",  linewidth=2.5, linestyle="--")
plt.xlim([-5,5]);plt.ylim([-1.5,1.5])
plt.xticks([-np.pi,0,np.pi],[r'-$\pi$',0,r'$\pi$'],fontsize=20) #Latex inside of pyplot
plt.yticks([-1,-0.5,0,0.5,1],fontsize=15)
ax = plt.gca()  # gca stands for 'get current axis'
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.spines['bottom'].set_position(('data',0))
ax.spines['left'].set_position(('data',0))
plt.legend([r'$\cos(x)$',r'$\sin(x)$'],fontsize=15)
plt.savefig('../Workspace/test.png',transparent=True)
plt.clf()

# %% [markdown]
# ## Saving plot (II)
#
# Show the plotted figure in the Markdown cell

# %% [markdown]
# ![image.png](../Workspace/test.png)

# %% [markdown]
# ## Figures, Subplots, Axes and Ticks

# %% [markdown]
# * Up to this point, we have let pyplot create a default figure and associated axes. This is the fast way of exploring data but becomes limiting when we want to make presentation or publication quality figures.
#
# * Now we will explore how to more directly control the figure, subplots, and axes directly.
#
# * Subplot position the plots in a regular grid while axes allows any placement within the figure. Subplots are safer but axes give you more freedom (and its associated responsility...).

# %% [markdown]
# ## Figures (there are many more args...)

# %%
fig = plt.figure(figsize=(10,2)) #Note that there are many arguments that you can pass here
plt.plot([3,4,5,])
plt.show()

# %%
fig = plt.figure(figsize=(3,3)) #Note that there are many arguments that you can pass here
plt.plot([3,4,5,])
plt.show()

# %% [markdown]
# ## Subplots
#
# With subplots you can arrange plots in a rectangular grid. You have to specify the rows and columns that are taken up by each plot.

# %%
plt.figure(figsize=(8,8))
plt.subplot(2,2,1)
plt.plot(np.random.randn(10))
plt.subplot(2,2,2)
plt.plot(np.random.randn(10))
plt.subplot(2,2,3)
plt.plot(np.random.randn(10))
plt.subplot(2,2,4)
plt.plot(np.random.randn(10))
plt.show()

# %% [markdown]
# ## Advanced subplots: Gridspec
#
# The gridspec module within matplotlib gives you a lot more control on the subplots.

# %%
import matplotlib.gridspec as gridspec

# %%
#Create the figure
plt.figure(figsize=(10,5))
#Define the grid spect
G = gridspec.GridSpec(2,3)
#Create the plots for each different section of the figure
plt.subplot(G[:,0])
plt.plot(np.random.randn(10))
plt.subplot(G[0,1:])
plt.plot(np.random.randn(10))
plt.subplot(G[1,1])
plt.plot(np.random.randn(10)) 
plt.subplot(G[1,2])
plt.plot(np.random.randn(10))
#Show the plot
plt.show()

# %% [markdown]
# ## Axes
#
# Axes are very similar to subplots but allow placement of plots at any location.
#
# **With great power comes great responsibility!**

# %%
#Define the first axis
plt.axes([0, 0, 1, 1])
plt.plot(np.linspace(0,1,10)/2)
#Define the second axis
plt.axes([0.07, 0.55, .4, .4])
#Create a histogram from a randomly sampled distribution
np.random.seed(1)
plt.hist(np.random.randn(10000),density=1,bins=100)
plt.show()

# %% [markdown]
# Let's show what is possible now. The following examples are taken "as is" from http://scipy-lectures.org/intro/matplotlib/index.html.

# %% [markdown]
# ## Plot and filled plots

# %%
n = 256
X = np.linspace(-np.pi, np.pi, n, endpoint=True)
Y = np.sin(2 * X)
plt.axes([0.025, 0.025, 0.95, 0.95])
plt.plot(X, Y + 1, color='blue', alpha=1.00)
plt.fill_between(X, 1, Y + 1, color='blue', alpha=.25)
plt.plot(X, Y - 1, color='blue', alpha=1.00)
plt.fill_between(X, -1, Y - 1, (Y - 1) > -1, color='blue', alpha=.25)
plt.fill_between(X, -1, Y - 1, (Y - 1) < -1, color='red',  alpha=.25)
plt.xlim(-np.pi, np.pi)
plt.xticks(())
plt.ylim(-2.5, 2.5)
plt.yticks(())   
plt.show()

# %% [markdown]
# ## Scatter plot

# %%
n = 1024
X = np.random.normal(0, 1, n)
Y = np.random.normal(0, 1, n)
T = np.arctan2(Y, X)
plt.axes([0.025, 0.025, 0.95, 0.95])
plt.scatter(X, Y, s=75, c=T, alpha=0.1)
plt.xlim(-1.5, 1.5)
plt.xticks(())
plt.ylim(-1.5, 1.5)
plt.yticks(())
plt.show()

# %% [markdown]
# ## Bar Plots

# %%
n = 12
X = np.arange(n)
Y1 = (1 - X / float(n)) * np.random.uniform(0.5, 1.0, n)
Y2 = (1 - X / float(n)) * np.random.uniform(0.5, 1.0, n)
plt.bar(X, +Y1, facecolor='#9999ff', edgecolor='white')
plt.bar(X, -Y2, facecolor='#ff9999', edgecolor='white')
for x, y in zip(X, Y1):
    plt.text(x + 0.4, y + 0.05, '%.2f' % y, ha='center', va='bottom')
plt.ylim(-1.25, +1.25)
# Out:
# (-1.25, 1.25)

# %% [markdown]
# ## Contour plot

# %%
def f(x, y):
    return (1 - x / 2 + x ** 5 + y ** 3) * np.exp(-x ** 2 -y ** 2)

n = 256
x = np.linspace(-3, 3, n)
y = np.linspace(-3, 3, n)
X, Y = np.meshgrid(x, y)
plt.contourf(X, Y, f(X, Y), 8, alpha=.75, cmap='jet')
C = plt.contour(X, Y, f(X, Y), 8, colors='black')

# %% [markdown]
# ## Imshow: Plotting a 2d array

# %%
def f(x, y):
    return (1 - x / 2 + x ** 5 + y ** 3 ) * np.exp(-x ** 2 - y ** 2)

n = 10
x = np.linspace(-3, 3, 3.5 * n)
y = np.linspace(-3, 3, 3.0 * n)
X, Y = np.meshgrid(x, y)
Z = f(X, Y)
plt.axes([0.025, 0.025, 0.95, 0.95])
plt.imshow(Z, interpolation='nearest', cmap=plt.get_cmap('terrain'), origin='lower')
plt.colorbar(shrink=.92)
plt.xticks(())
plt.yticks(())
plt.show()

# %% [markdown]
# ## Pie charts

# %%
n = 20
Z = np.ones(n)
Z[-1] *= 2
plt.axes([0.025, 0.025, 0.95, 0.95])
plt.pie(Z, explode=Z*.05, colors = ['%f' % (i/float(n)) for i in range(n)])
plt.axis('equal')
plt.xticks(())
plt.yticks()
plt.show()

# %% [markdown]
# ## Histogram

# %%
np.random.seed(1)
x = np.random.randn(10000)
plt.hist(x, bins=50, density=1, facecolor='r', alpha=0.5)
plt.xlabel('Values',fontsize=15)
plt.ylabel('Probability',fontsize=15)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.title('Standard normal distribution',fontsize=20)
plt.text(1,0.35, r'$\mu=0,\ \sigma=1$',fontsize=20)
plt.show()

# %% [markdown]
# ## Environmental data
#
# Let's now explore some plots with actual environmental data. We will use the ERA-Interim data that we used last lecture.

# %% [markdown]
# ## Comparing 2015 temperature at different sites
#
# Start off by defining the coordinates for three different sites

# %%
sites = {'seattle':{'lat':47.6062,'lon':-122.3321},
         'paris':{'lat':48.8566,'lon':2.3522},
         'santiago':{'lat':-33.4489,'lon':-70.6693}}

# %% [markdown]
# Let's now read in the metadata from the ERA-Interim file

# %%
import netCDF4 as nc
file = '/shared_space/data/era-interim/era_interim_monthly_197901_201512_upscaled.nc'
fp = nc.Dataset(file)
lats = fp['lat'][:]
lons = fp['lon'][:]
times = fp['time']
plt.pcolormesh(fp['t2m'][0,:,:])
plt.show()

# %% [markdown]
# Let's plot the lat and lon arrays:

# %%
plt.figure(figsize=(10,3))
plt.subplot(121)
plt.title('latitudes',fontsize=15)
plt.plot(lats,lw=3)
plt.subplot(122)
plt.title('longitudes',fontsize=15)
plt.plot(lons,lw=3)
plt.show()

# %% [markdown]
# Let's now compute the ilat/ilon for each of these sites and add it to the dictionary

# %%
#Look for the closest grid cell center for each site
for site in sites:
    lat = sites[site]['lat']
    lon = sites[site]['lon']
    if lon < 0:lon = 360 + lon
    sites[site]['ilat'] = int(np.argmin(np.abs(lats - lat)))
    sites[site]['ilon'] = int(np.argmin(np.abs(lons - lon)))
print(sites)
# Out:
# {'seattle': {'lat': 47.6062, 'lon': -122.3321, 'ilat': 137, 'ilon': 190}, 'paris': {'lat': 48.8566, 'lon': 2.3522, 'ilat': 138, 'ilon': 1}, 'santiago': {'lat': -33.4489, 'lon': -70.6693, 'ilat': 56, 'ilon': 231}}

# %% [markdown]
# Read in the times as a datetime array

# %%
import datetime
#Convert the dates to a datetime array
dates = nc.num2date(times[:],units=times.units,calendar=times.calendar)
print(dates)
# Out:
# [datetime.datetime(1979, 1, 16, 12, 0)
#  datetime.datetime(1979, 2, 15, 0, 0)
#  datetime.datetime(1979, 3, 16, 12, 0)
#  datetime.datetime(1979, 4, 16, 0, 0)
#  datetime.datetime(1979, 5, 16, 12, 0)
#  datetime.datetime(1979, 6, 16, 0, 0)
#  datetime.datetime(1979, 7, 16, 12, 0)
#  datetime.datetime(1979, 8, 16, 12, 0)
#  datetime.datetime(1979, 9, 16, 0, 0)
#  datetime.datetime(1979, 10, 16, 12, 0)
#  datetime.datetime(1979, 11, 16, 0, 0)
#  datetime.datetime(1979, 12, 16, 12, 0)
#  datetime.datetime(1980, 1, 16, 12, 0)
#  datetime.datetime(1980, 2, 15, 12, 0)
#  datetime.datetime(1980, 3, 16, 12, 0)
#  datetime.datetime(1980, 4, 16, 0, 0)
#  datetime.datetime(1980, 5, 16, 12, 0)
#  datetime.datetime(1980, 6, 16, 0, 0)
#  datetime.datetime(1980, 7, 16, 12, 0)
#  datetime.datetime(1980, 8, 16, 12, 0)
#  datetime.datetime(1980, 9, 16, 0, 0)
#  datetime.datetime(1980, 10, 16, 12, 0)
#  datetime.datetime(1980, 11, 16, 0, 0)
#  datetime.datetime(1980, 12, 16, 12, 0)
#  datetime.datetime(1981, 1, 16, 12, 0)
#  datetime.datetime(1981, 2, 15, 0, 0)
#  datetime.datetime(1981, 3, 16, 12, 0)
#  datetime.datetime(1981, 4, 16, 0, 0)
#  datetime.datetime(1981, 5, 16, 12, 0)
#  datetime.datetime(1981, 6, 16, 0, 0)
#  datetime.datetime(1981, 7, 16, 12, 0)
#  datetime.datetime(1981, 8, 16, 12, 0)
#  datetime.datetime(1981, 9, 16, 0, 0)
#  datetime.datetime(1981, 10, 16, 12, 0)
#  datetime.datetime(1981, 11, 16, 0, 0)
#  datetime.datetime(1981, 12, 16, 12, 0)
#  datetime.datetime(1982, 1, 16, 12, 0)
#  datetime.datetime(1982, 2, 15, 0, 0)
#  datetime.datetime(1982, 3, 16, 12, 0)
#  datetime.datetime(1982, 4, 16, 0, 0)
#  datetime.datetime(1982, 5, 16, 12, 0)
#  datetime.datetime(1982, 6, 16, 0, 0)
#  datetime.datetime(1982, 7, 16, 12, 0)
#  datetime.datetime(1982, 8, 16, 12, 0)
#  datetime.datetime(1982, 9, 16, 0, 0)
#  datetime.datetime(1982, 10, 16, 12, 0)
#  datetime.datetime(1982, 11, 16, 0, 0)
#  datetime.datetime(1982, 12, 16, 12, 0)
#  datetime.datetime(1983, 1, 16, 12, 0)
#  datetime.datetime(1983, 2, 15, 0, 0)
#  datetime.datetime(1983, 3, 16, 12, 0)
#  datetime.datetime(1983, 4, 16, 0, 0)
#  datetime.datetime(1983, 5, 16, 12, 0)
#  datetime.datetime(1983, 6, 16, 0, 0)
#  datetime.datetime(1983, 7, 16, 12, 0)
#  datetime.datetime(1983, 8, 16, 12, 0)
#  datetime.datetime(1983, 9, 16, 0, 0)
#  datetime.datetime(1983, 10, 16, 12, 0)
#  datetime.datetime(1983, 11, 16, 0, 0)
#  datetime.datetime(1983, 12, 16, 12, 0)
#  datetime.datetime(1984, 1, 16, 12, 0)
#  datetime.datetime(1984, 2, 15, 12, 0)
#  datetime.datetime(1984, 3, 16, 12, 0)
#  datetime.datetime(1984, 4, 16, 0, 0)
#  datetime.datetime(1984, 5, 16, 12, 0)
#  datetime.datetime(1984, 6, 16, 0, 0)
#  datetime.datetime(1984, 7, 16, 12, 0)
#  datetime.datetime(1984, 8, 16, 12, 0)
#  datetime.datetime(1984, 9, 16, 0, 0)
#  datetime.datetime(1984, 10, 16, 12, 0)
#  datetime.datetime(1984, 11, 16, 0, 0)
#  datetime.datetime(1984, 12, 16, 12, 0)
#  datetime.datetime(1985, 1, 16, 12, 0)
#  datetime.datetime(1985, 2, 15, 0, 0)
#  datetime.datetime(1985, 3, 16, 12, 0)
#  datetime.datetime(1985, 4, 16, 0, 0)
#  datetime.datetime(1985, 5, 16, 12, 0)
#  datetime.datetime(1985, 6, 16, 0, 0)
#  datetime.datetime(1985, 7, 16, 12, 0)
#  datetime.datetime(1985, 8, 16, 12, 0)
#  datetime.datetime(1985, 9, 16, 0, 0)
#  datetime.datetime(1985, 10, 16, 12, 0)
#  datetime.datetime(1985, 11, 16, 0, 0)
#  datetime.datetime(1985, 12, 16, 12, 0)
#  datetime.datetime(1986, 1, 16, 12, 0)
#  datetime.datetime(1986, 2, 15, 0, 0)
#  datetime.datetime(1986, 3, 16, 12, 0)
#  datetime.datetime(1986, 4, 16, 0, 0)
#  datetime.datetime(1986, 5, 16, 12, 0)
#  datetime.datetime(1986, 6, 16, 0, 0)
#  datetime.datetime(1986, 7, 16, 12, 0)
#  datetime.datetime(1986, 8, 16, 12, 0)
#  datetime.datetime(1986, 9, 16, 0, 0)
#  datetime.datetime(1986, 10, 16, 12, 0)
#  datetime.datetime(1986, 11, 16, 0, 0)
#  datetime.datetime(1986, 12, 16, 12, 0)
#  datetime.datetime(1987, 1, 16, 12, 0)
#  datetime.datetime(1987, 2, 15, 0, 0)
#  datetime.datetime(1987, 3, 16, 12, 0)
#  datetime.datetime(1987, 4, 16, 0, 0)
#  datetime.datetime(1987, 5, 16, 12, 0)
#  datetime.datetime(1987, 6, 16, 0, 0)
#  datetime.datetime(1987, 7, 16, 12, 0)
#  datetime.datetime(1987, 8, 16, 12, 0)
#  datetime.datetime(1987, 9, 16, 0, 0)
#  datetime.datetime(1987, 10, 16, 12, 0)
#  datetime.datetime(1987, 11, 16, 0, 0)
#  datetime.datetime(1987, 12, 16, 12, 0)
#  datetime.datetime(1988, 1, 16, 12, 0)
#  datetime.datetime(1988, 2, 15, 12, 0)
#  datetime.datetime(1988, 3, 16, 12, 0)
#  datetime.datetime(1988, 4, 16, 0, 0)
#  datetime.datetime(1988, 5, 16, 12, 0)
#  datetime.datetime(1988, 6, 16, 0, 0)
#  datetime.datetime(1988, 7, 16, 12, 0)
#  datetime.datetime(1988, 8, 16, 12, 0)
#  datetime.datetime(1988, 9, 16, 0, 0)
#  datetime.datetime(1988, 10, 16, 12, 0)
#  datetime.datetime(1988, 11, 16, 0, 0)
#  datetime.datetime(1988, 12, 16, 12, 0)
#  datetime.datetime(1989, 1, 16, 12, 0)
#  datetime.datetime(1989, 2, 15, 0, 0)
#  datetime.datetime(1989, 3, 16, 12, 0)
#  datetime.datetime(1989, 4, 16, 0, 0)
#  datetime.datetime(1989, 5, 16, 12, 0)
#  datetime.datetime(1989, 6, 16, 0, 0)
#  datetime.datetime(1989, 7, 16, 12, 0)
#  datetime.datetime(1989, 8, 16, 12, 0)
#  datetime.datetime(1989, 9, 16, 0, 0)
#  datetime.datetime(1989, 10, 16, 12, 0)
#  datetime.datetime(1989, 11, 16, 0, 0)
#  datetime.datetime(1989, 12, 16, 12, 0)
#  datetime.datetime(1990, 1, 16, 12, 0)
#  datetime.datetime(1990, 2, 15, 0, 0)
#  datetime.datetime(1990, 3, 16, 12, 0)
#  datetime.datetime(1990, 4, 16, 0, 0)
#  datetime.datetime(1990, 5, 16, 12, 0)
#  datetime.datetime(1990, 6, 16, 0, 0)
#  datetime.datetime(1990, 7, 16, 12, 0)
#  datetime.datetime(1990, 8, 16, 12, 0)
#  datetime.datetime(1990, 9, 16, 0, 0)
#  datetime.datetime(1990, 10, 16, 12, 0)
#  datetime.datetime(1990, 11, 16, 0, 0)
#  datetime.datetime(1990, 12, 16, 12, 0)
#  datetime.datetime(1991, 1, 16, 12, 0)
#  datetime.datetime(1991, 2, 15, 0, 0)
#  datetime.datetime(1991, 3, 16, 12, 0)
#  datetime.datetime(1991, 4, 16, 0, 0)
#  datetime.datetime(1991, 5, 16, 12, 0)
#  datetime.datetime(1991, 6, 16, 0, 0)
#  datetime.datetime(1991, 7, 16, 12, 0)
#  datetime.datetime(1991, 8, 16, 12, 0)
#  datetime.datetime(1991, 9, 16, 0, 0)
#  datetime.datetime(1991, 10, 16, 12, 0)
#  datetime.datetime(1991, 11, 16, 0, 0)
#  datetime.datetime(1991, 12, 16, 12, 0)
#  datetime.datetime(1992, 1, 16, 12, 0)
#  datetime.datetime(1992, 2, 15, 12, 0)
#  datetime.datetime(1992, 3, 16, 12, 0)
#  datetime.datetime(1992, 4, 16, 0, 0)
#  datetime.datetime(1992, 5, 16, 12, 0)
#  datetime.datetime(1992, 6, 16, 0, 0)
#  datetime.datetime(1992, 7, 16, 12, 0)
#  datetime.datetime(1992, 8, 16, 12, 0)
#  datetime.datetime(1992, 9, 16, 0, 0)
#  datetime.datetime(1992, 10, 16, 12, 0)
#  datetime.datetime(1992, 11, 16, 0, 0)
#  datetime.datetime(1992, 12, 16, 12, 0)
#  datetime.datetime(1993, 1, 16, 12, 0)
#  datetime.datetime(1993, 2, 15, 0, 0)
#  datetime.datetime(1993, 3, 16, 12, 0)
#  datetime.datetime(1993, 4, 16, 0, 0)
#  datetime.datetime(1993, 5, 16, 12, 0)
#  datetime.datetime(1993, 6, 16, 0, 0)
#  datetime.datetime(1993, 7, 16, 12, 0)
#  datetime.datetime(1993, 8, 16, 12, 0)
#  datetime.datetime(1993, 9, 16, 0, 0)
#  datetime.datetime(1993, 10, 16, 12, 0)
#  datetime.datetime(1993, 11, 16, 0, 0)
#  datetime.datetime(1993, 12, 16, 12, 0)
#  datetime.datetime(1994, 1, 16, 12, 0)
#  datetime.datetime(1994, 2, 15, 0, 0)
#  datetime.datetime(1994, 3, 16, 12, 0)
#  datetime.datetime(1994, 4, 16, 0, 0)
#  datetime.datetime(1994, 5, 16, 12, 0)
#  datetime.datetime(1994, 6, 16, 0, 0)
#  datetime.datetime(1994, 7, 16, 12, 0)
#  datetime.datetime(1994, 8, 16, 12, 0)
#  datetime.datetime(1994, 9, 16, 0, 0)
#  datetime.datetime(1994, 10, 16, 12, 0)
#  datetime.datetime(1994, 11, 16, 0, 0)
#  datetime.datetime(1994, 12, 16, 12, 0)
#  datetime.datetime(1995, 1, 16, 12, 0)
#  datetime.datetime(1995, 2, 15, 0, 0)
#  datetime.datetime(1995, 3, 16, 12, 0)
#  datetime.datetime(1995, 4, 16, 0, 0)
#  datetime.datetime(1995, 5, 16, 12, 0)
#  datetime.datetime(1995, 6, 16, 0, 0)
#  datetime.datetime(1995, 7, 16, 12, 0)
#  datetime.datetime(1995, 8, 16, 12, 0)
#  datetime.datetime(1995, 9, 16, 0, 0)
#  datetime.datetime(1995, 10, 16, 12, 0)
#  datetime.datetime(1995, 11, 16, 0, 0)
#  datetime.datetime(1995, 12, 16, 12, 0)
#  datetime.datetime(1996, 1, 16, 12, 0)
#  datetime.datetime(1996, 2, 15, 12, 0)
#  datetime.datetime(1996, 3, 16, 12, 0)
#  datetime.datetime(1996, 4, 16, 0, 0)
#  datetime.datetime(1996, 5, 16, 12, 0)
#  datetime.datetime(1996, 6, 16, 0, 0)
#  datetime.datetime(1996, 7, 16, 12, 0)
#  datetime.datetime(1996, 8, 16, 12, 0)
#  datetime.datetime(1996, 9, 16, 0, 0)
#  datetime.datetime(1996, 10, 16, 12, 0)
#  datetime.datetime(1996, 11, 16, 0, 0)
#  datetime.datetime(1996, 12, 16, 12, 0)
#  datetime.datetime(1997, 1, 16, 12, 0)
#  datetime.datetime(1997, 2, 15, 0, 0)
#  datetime.datetime(1997, 3, 16, 12, 0)
#  datetime.datetime(1997, 4, 16, 0, 0)
#  datetime.datetime(1997, 5, 16, 12, 0)
#  datetime.datetime(1997, 6, 16, 0, 0)
#  datetime.datetime(1997, 7, 16, 12, 0)
#  datetime.datetime(1997, 8, 16, 12, 0)
#  datetime.datetime(1997, 9, 16, 0, 0)
#  datetime.datetime(1997, 10, 16, 12, 0)
#  datetime.datetime(1997, 11, 16, 0, 0)
#  datetime.datetime(1997, 12, 16, 12, 0)
#  datetime.datetime(1998, 1, 16, 12, 0)
#  datetime.datetime(1998, 2, 15, 0, 0)
#  datetime.datetime(1998, 3, 16, 12, 0)
#  datetime.datetime(1998, 4, 16, 0, 0)
#  datetime.datetime(1998, 5, 16, 12, 0)
#  datetime.datetime(1998, 6, 16, 0, 0)
#  datetime.datetime(1998, 7, 16, 12, 0)
#  datetime.datetime(1998, 8, 16, 12, 0)
#  datetime.datetime(1998, 9, 16, 0, 0)
#  datetime.datetime(1998, 10, 16, 12, 0)
#  datetime.datetime(1998, 11, 16, 0, 0)
#  datetime.datetime(1998, 12, 16, 12, 0)
#  datetime.datetime(1999, 1, 16, 12, 0)
#  datetime.datetime(1999, 2, 15, 0, 0)
#  datetime.datetime(1999, 3, 16, 12, 0)
#  datetime.datetime(1999, 4, 16, 0, 0)
#  datetime.datetime(1999, 5, 16, 12, 0)
#  datetime.datetime(1999, 6, 16, 0, 0)
#  datetime.datetime(1999, 7, 16, 12, 0)
#  datetime.datetime(1999, 8, 16, 12, 0)
#  datetime.datetime(1999, 9, 16, 0, 0)
#  datetime.datetime(1999, 10, 16, 12, 0)
#  datetime.datetime(1999, 11, 16, 0, 0)
#  datetime.datetime(1999, 12, 16, 12, 0)
#  datetime.datetime(2000, 1, 16, 12, 0)
#  datetime.datetime(2000, 2, 15, 12, 0)
#  datetime.datetime(2000, 3, 16, 12, 0)
#  datetime.datetime(2000, 4, 16, 0, 0)
#  datetime.datetime(2000, 5, 16, 12, 0)
#  datetime.datetime(2000, 6, 16, 0, 0)
#  datetime.datetime(2000, 7, 16, 12, 0)
#  datetime.datetime(2000, 8, 16, 12, 0)
#  datetime.datetime(2000, 9, 16, 0, 0)
#  datetime.datetime(2000, 10, 16, 12, 0)
#  datetime.datetime(2000, 11, 16, 0, 0)
#  datetime.datetime(2000, 12, 16, 12, 0)
#  datetime.datetime(2001, 1, 16, 12, 0)
#  datetime.datetime(2001, 2, 15, 0, 0)
#  datetime.datetime(2001, 3, 16, 12, 0)
#  datetime.datetime(2001, 4, 16, 0, 0)
#  datetime.datetime(2001, 5, 16, 12, 0)
#  datetime.datetime(2001, 6, 16, 0, 0)
#  datetime.datetime(2001, 7, 16, 12, 0)
#  datetime.datetime(2001, 8, 16, 12, 0)
#  datetime.datetime(2001, 9, 16, 0, 0)
#  datetime.datetime(2001, 10, 16, 12, 0)
#  datetime.datetime(2001, 11, 16, 0, 0)
#  datetime.datetime(2001, 12, 16, 12, 0)
#  datetime.datetime(2002, 1, 16, 12, 0)
#  datetime.datetime(2002, 2, 15, 0, 0)
#  datetime.datetime(2002, 3, 16, 12, 0)
#  datetime.datetime(2002, 4, 16, 0, 0)
#  datetime.datetime(2002, 5, 16, 12, 0)
#  datetime.datetime(2002, 6, 16, 0, 0)
#  datetime.datetime(2002, 7, 16, 12, 0)
#  datetime.datetime(2002, 8, 16, 12, 0)
#  datetime.datetime(2002, 9, 16, 0, 0)
#  datetime.datetime(2002, 10, 16, 12, 0)
#  datetime.datetime(2002, 11, 16, 0, 0)
#  datetime.datetime(2002, 12, 16, 12, 0)
#  datetime.datetime(2003, 1, 16, 12, 0)
#  datetime.datetime(2003, 2, 15, 0, 0)
#  datetime.datetime(2003, 3, 16, 12, 0)
#  datetime.datetime(2003, 4, 16, 0, 0)
#  datetime.datetime(2003, 5, 16, 12, 0)
#  datetime.datetime(2003, 6, 16, 0, 0)
#  datetime.datetime(2003, 7, 16, 12, 0)
#  datetime.datetime(2003, 8, 16, 12, 0)
#  datetime.datetime(2003, 9, 16, 0, 0)
#  datetime.datetime(2003, 10, 16, 12, 0)
#  datetime.datetime(2003, 11, 16, 0, 0)
#  datetime.datetime(2003, 12, 16, 12, 0)
#  datetime.datetime(2004, 1, 16, 12, 0)
#  datetime.datetime(2004, 2, 15, 12, 0)
#  datetime.datetime(2004, 3, 16, 12, 0)
#  datetime.datetime(2004, 4, 16, 0, 0)
#  datetime.datetime(2004, 5, 16, 12, 0)
#  datetime.datetime(2004, 6, 16, 0, 0)
#  datetime.datetime(2004, 7, 16, 12, 0)
#  datetime.datetime(2004, 8, 16, 12, 0)
#  datetime.datetime(2004, 9, 16, 0, 0)
#  datetime.datetime(2004, 10, 16, 12, 0)
#  datetime.datetime(2004, 11, 16, 0, 0)
#  datetime.datetime(2004, 12, 16, 12, 0)
#  datetime.datetime(2005, 1, 16, 12, 0)
#  datetime.datetime(2005, 2, 15, 0, 0)
#  datetime.datetime(2005, 3, 16, 12, 0)
#  datetime.datetime(2005, 4, 16, 0, 0)
#  datetime.datetime(2005, 5, 16, 12, 0)
#  datetime.datetime(2005, 6, 16, 0, 0)
#  datetime.datetime(2005, 7, 16, 12, 0)
#  datetime.datetime(2005, 8, 16, 12, 0)
#  datetime.datetime(2005, 9, 16, 0, 0)
#  datetime.datetime(2005, 10, 16, 12, 0)
#  datetime.datetime(2005, 11, 16, 0, 0)
#  datetime.datetime(2005, 12, 16, 12, 0)
#  datetime.datetime(2006, 1, 16, 12, 0)
#  datetime.datetime(2006, 2, 15, 0, 0)
#  datetime.datetime(2006, 3, 16, 12, 0)
#  datetime.datetime(2006, 4, 16, 0, 0)
#  datetime.datetime(2006, 5, 16, 12, 0)
#  datetime.datetime(2006, 6, 16, 0, 0)
#  datetime.datetime(2006, 7, 16, 12, 0)
#  datetime.datetime(2006, 8, 16, 12, 0)
#  datetime.datetime(2006, 9, 16, 0, 0)
#  datetime.datetime(2006, 10, 16, 12, 0)
#  datetime.datetime(2006, 11, 16, 0, 0)
#  datetime.datetime(2006, 12, 16, 12, 0)
#  datetime.datetime(2007, 1, 16, 12, 0)
#  datetime.datetime(2007, 2, 15, 0, 0)
#  datetime.datetime(2007, 3, 16, 12, 0)
#  datetime.datetime(2007, 4, 16, 0, 0)
#  datetime.datetime(2007, 5, 16, 12, 0)
#  datetime.datetime(2007, 6, 16, 0, 0)
#  datetime.datetime(2007, 7, 16, 12, 0)
#  datetime.datetime(2007, 8, 16, 12, 0)
#  datetime.datetime(2007, 9, 16, 0, 0)
#  datetime.datetime(2007, 10, 16, 12, 0)
#  datetime.datetime(2007, 11, 16, 0, 0)
#  datetime.datetime(2007, 12, 16, 12, 0)
#  datetime.datetime(2008, 1, 16, 12, 0)
#  datetime.datetime(2008, 2, 15, 12, 0)
#  datetime.datetime(2008, 3, 16, 12, 0)
#  datetime.datetime(2008, 4, 16, 0, 0)
#  datetime.datetime(2008, 5, 16, 12, 0)
#  datetime.datetime(2008, 6, 16, 0, 0)
#  datetime.datetime(2008, 7, 16, 12, 0)
#  datetime.datetime(2008, 8, 16, 12, 0)
#  datetime.datetime(2008, 9, 16, 0, 0)
#  datetime.datetime(2008, 10, 16, 12, 0)
#  datetime.datetime(2008, 11, 16, 0, 0)
#  datetime.datetime(2008, 12, 16, 12, 0)
#  datetime.datetime(2009, 1, 16, 12, 0)
#  datetime.datetime(2009, 2, 15, 0, 0)
#  datetime.datetime(2009, 3, 16, 12, 0)
#  datetime.datetime(2009, 4, 16, 0, 0)
#  datetime.datetime(2009, 5, 16, 12, 0)
#  datetime.datetime(2009, 6, 16, 0, 0)
#  datetime.datetime(2009, 7, 16, 12, 0)
#  datetime.datetime(2009, 8, 16, 12, 0)
#  datetime.datetime(2009, 9, 16, 0, 0)
#  datetime.datetime(2009, 10, 16, 12, 0)
#  datetime.datetime(2009, 11, 16, 0, 0)
#  datetime.datetime(2009, 12, 16, 12, 0)
#  datetime.datetime(2010, 1, 16, 12, 0)
#  datetime.datetime(2010, 2, 15, 0, 0)
#  datetime.datetime(2010, 3, 16, 12, 0)
#  datetime.datetime(2010, 4, 16, 0, 0)
#  datetime.datetime(2010, 5, 16, 12, 0)
#  datetime.datetime(2010, 6, 16, 0, 0)
#  datetime.datetime(2010, 7, 16, 12, 0)
#  datetime.datetime(2010, 8, 16, 12, 0)
#  datetime.datetime(2010, 9, 16, 0, 0)
#  datetime.datetime(2010, 10, 16, 12, 0)
#  datetime.datetime(2010, 11, 16, 0, 0)
#  datetime.datetime(2010, 12, 16, 12, 0)
#  datetime.datetime(2011, 1, 16, 12, 0)
#  datetime.datetime(2011, 2, 15, 0, 0)
#  datetime.datetime(2011, 3, 16, 12, 0)
#  datetime.datetime(2011, 4, 16, 0, 0)
#  datetime.datetime(2011, 5, 16, 12, 0)
#  datetime.datetime(2011, 6, 16, 0, 0)
#  datetime.datetime(2011, 7, 16, 12, 0)
#  datetime.datetime(2011, 8, 16, 12, 0)
#  datetime.datetime(2011, 9, 16, 0, 0)
#  datetime.datetime(2011, 10, 16, 12, 0)
#  datetime.datetime(2011, 11, 16, 0, 0)
#  datetime.datetime(2011, 12, 16, 12, 0)
#  datetime.datetime(2012, 1, 16, 12, 0)
#  datetime.datetime(2012, 2, 15, 12, 0)
#  datetime.datetime(2012, 3, 16, 12, 0)
#  datetime.datetime(2012, 4, 16, 0, 0)
#  datetime.datetime(2012, 5, 16, 12, 0)
#  datetime.datetime(2012, 6, 16, 0, 0)
#  datetime.datetime(2012, 7, 16, 12, 0)
#  datetime.datetime(2012, 8, 16, 12, 0)
#  datetime.datetime(2012, 9, 16, 0, 0)
#  datetime.datetime(2012, 10, 16, 12, 0)
#  datetime.datetime(2012, 11, 16, 0, 0)
#  datetime.datetime(2012, 12, 16, 12, 0)
#  datetime.datetime(2013, 1, 16, 12, 0)
#  datetime.datetime(2013, 2, 15, 0, 0)
#  datetime.datetime(2013, 3, 16, 12, 0)
#  datetime.datetime(2013, 4, 16, 0, 0)
#  datetime.datetime(2013, 5, 16, 12, 0)
#  datetime.datetime(2013, 6, 16, 0, 0)
#  datetime.datetime(2013, 7, 16, 12, 0)
#  datetime.datetime(2013, 8, 16, 12, 0)
#  datetime.datetime(2013, 9, 16, 0, 0)
#  datetime.datetime(2013, 10, 16, 12, 0)
#  datetime.datetime(2013, 11, 16, 0, 0)
#  datetime.datetime(2013, 12, 16, 12, 0)
#  datetime.datetime(2014, 1, 16, 12, 0)
#  datetime.datetime(2014, 2, 15, 0, 0)
#  datetime.datetime(2014, 3, 16, 12, 0)
#  datetime.datetime(2014, 4, 16, 0, 0)
#  datetime.datetime(2014, 5, 16, 12, 0)
#  datetime.datetime(2014, 6, 16, 0, 0)
#  datetime.datetime(2014, 7, 16, 12, 0)
#  datetime.datetime(2014, 8, 16, 12, 0)
#  datetime.datetime(2014, 9, 16, 0, 0)
#  datetime.datetime(2014, 10, 16, 12, 0)
#  datetime.datetime(2014, 11, 16, 0, 0)
#  datetime.datetime(2014, 12, 16, 12, 0)
#  datetime.datetime(2015, 1, 16, 12, 0)
#  datetime.datetime(2015, 2, 15, 0, 0)
#  datetime.datetime(2015, 3, 16, 12, 0)
#  datetime.datetime(2015, 4, 16, 0, 0)
#  datetime.datetime(2015, 5, 16, 12, 0)
#  datetime.datetime(2015, 6, 16, 0, 0)
#  datetime.datetime(2015, 7, 16, 12, 0)
#  datetime.datetime(2015, 8, 16, 12, 0)
#  datetime.datetime(2015, 9, 16, 0, 0)
#  datetime.datetime(2015, 10, 16, 12, 0)
#  datetime.datetime(2015, 11, 16, 0, 0)
#  datetime.datetime(2015, 12, 16, 12, 0)]

# %% [markdown]
# Now we can extract the data for the variable `t2m`.

# %%
var = 't2m'
#Iterate through all the sites
for site in sites:
    #Extract the data for the given site
    ilat = sites[site]['ilat']
    ilon = sites[site]['ilon']
    sites[site][var] = fp[var][:,ilat,ilon]
print(sites)
# Out:
# {'seattle': {'lat': 47.6062, 'lon': -122.3321, 'ilat': 137, 'ilon': 190, 't2m': masked_array(data=[-2.8908904 ,  1.8307246 ,  5.851398  ,  7.6605945 ,
#                    11.840046  , 14.691407  , 17.733408  , 16.796717  ,
#                    15.24787   , 10.68557   ,  3.4741604 ,  3.6767967 ,
#                    -1.7208128 ,  2.983806  ,  4.0873055 ,  8.892719  ,
#                    10.834371  , 12.489746  , 16.384287  , 15.185278  ,
#                    13.595211  , 10.057309  ,  5.8435388 ,  4.0769777 ,
#                     3.8048556 ,  3.3925412 ,  6.1889343 ,  7.176038  ,
#                     8.96985  , 12.179677 , 15.19075  , 16.642567 ,
#                    19.3635   , 18.886974 , 16.485502 , 12.545176 ,
#                     9.192963 ,  5.8864055,  4.150616 ,  5.910659 ,
#                     9.918306 , 12.140017 , 15.599223 , 19.026167 ,
#                    19.560003 , 19.771072 , 18.741379 , 13.517599 ,
#                    10.94089  ,  7.923844 ,  5.598491 ,  6.938858 ,
#                    10.793978 , 11.650694 , 16.529835 , 17.45197  ,
#                    20.339314 , 19.871859 , 16.36441  , 12.887532 ,
#                     8.909835 ,  6.37683  ,  6.012916 ,  6.525573 ,
#                     9.108604 , 12.60139  , 15.196485 , 19.321499 ,
#                    20.281858 , 18.198648 , 16.265217 , 12.35313  ,
#                     9.728567 ,  5.5011597,  6.086979 ,  8.248958 ,
#                     8.902311 , 13.842539 , 15.28852  , 17.450047 ,
#                    20.612059 , 19.330748 , 18.653358 , 14.429055 ,
#                     9.152667 ,  7.156456 ,  6.0013847,  7.9477105,
#                     9.043811 , 10.819689 , 14.1514845, 18.265982 ],
#              mask=False,
#        fill_value=1e+20,
#             dtype=float32)}}

# %% [markdown]
# Let's make a plot only for 2015

# %%
#Calculate the Boolean mask for dates within 2015
m = (dates >= datetime.datetime(2015,1,1)) & (dates <= datetime.datetime(2015,12,31))
#Assemble the subsetted dates array
dates_subset = dates[m]

plt.figure(figsize=(10,7))
plt.plot(dates_subset,sites['seattle']['t2m'][m],lw=7)
plt.plot(dates_subset,sites['paris']['t2m'][m],lw=7)
plt.plot(dates_subset,sites['santiago']['t2m'][m],lw=7)
plt.xticks(fontsize=20,rotation=35)
plt.yticks(fontsize=20,rotation=35)
plt.xlabel('date',fontsize=30)
plt.ylabel(r'$^o$C',fontsize=30)
plt.grid('on')
plt.legend(['Seattle','Paris','Santiago'],fontsize=25)
plt.show()

# %% [markdown]
# Let's create some scatter plots to compare the three sites

# %%
fig = plt.figure(figsize=(10,10))
i = 0
for site1 in sites:
    for site2 in sites:
        i = i + 1
        plt.subplot(3,3,i)
        plt.plot(sites[site1]['t2m'],sites[site2]['t2m'],'bo',alpha=0.2)
        plt.plot(sites[site1]['t2m'],sites[site1]['t2m'],'r',lw=3)
        plt.xticks(fontsize=15)
        plt.yticks(fontsize=15)
        plt.title('%s (x) vs %s (y)' % (site1,site2),fontsize=15)
        if i in [7,8,9]:plt.xlabel(r'$^o$C',fontsize=20)
        if i in [1,4,7]:plt.ylabel(r'$^o$C',fontsize=20)
fig.tight_layout()
plt.show()

# %% [markdown]
# You could also use hexbins to show the same thing but prettier*!

# %%
fig = plt.figure(figsize=(10,10))
i = 0
for site1 in sites:
    for site2 in sites:
        i = i + 1
        plt.subplot(3,3,i)
        plt.hexbin(sites[site1]['t2m'],sites[site2]['t2m'],gridsize=10,cmap=plt.get_cmap('binary'))
        plt.plot(sites[site1]['t2m'],sites[site1]['t2m'],'r',lw=3)
        plt.xticks(fontsize=15)
        plt.yticks(fontsize=15)
        plt.title('%s (x) vs %s (y)' % (site1,site2),fontsize=15)
        if i in [7,8,9]:plt.xlabel(r'$^o$C',fontsize=20)
        if i in [1,4,7]:plt.ylabel(r'$^o$C',fontsize=20)
fig.tight_layout()
plt.show()

# %% [markdown]
# # Let's look at making maps now

# %% [markdown]
# We will start with the example from Tuesday's lecture

# %%
data = fp['t2m'][:]

# %%
plt.figure(figsize=(10,10))
plt.imshow(np.flipud(data[-1,:,:]),cmap=plt.get_cmap('RdBu_r'))
plt.axis('off')
plt.title('ERA interim (%02d/%04d)' % (dates[-1].month,dates[-1].year),fontsize=20)
cb = plt.colorbar(orientation='horizontal',shrink=0.8,pad=0.05)
cb.ax.tick_params(labelsize=15)
cb.set_label('Monthly temperature ($^o$C)',fontsize=20)
plt.show()

# %% [markdown]
# Let's now show a map for the annual average from 1979-2015 of each month.

# %%
fig = plt.figure(figsize=(10,10))
for month in range(1,13):
    plt.subplot(4,3,month)
    #Extract the data a given month for all years
    tmp = data[month-1::12,:,:]
    #Calculate the temporal mean of that data
    tmp = np.mean(tmp,axis=0)
    im = plt.imshow(np.flipud(tmp),cmap=plt.get_cmap('RdBu_r'))
    plt.axis('off')
    plt.title('Month: %d' % month,fontsize=20)
#Let's place a colorbar
cb_ax = fig.add_axes([0.92, 0.2, 0.03, 0.6])
cb = fig.colorbar(im, cax=cb_ax)
cb.ax.tick_params(labelsize=15)
plt.show()

# %% [markdown]
# We could do contours instead of showing every pixel value as well

# %%
plt.figure(figsize=(10,10))
tmp = np.mean(data,axis=0)
plt.contourf(tmp,levels=100,cmap=plt.get_cmap('RdBu_r'))
plt.axis('off')
plt.title('Annual average',fontsize=20)
cb = plt.colorbar(orientation='horizontal',shrink=0.8,pad=0.05)
cb.ax.tick_params(labelsize=15)
cb.set_label('Monthly temperature ($^o$C)',fontsize=20)
plt.show()

# %% [markdown]
# ## Colormaps
#
# We can quickly change the colormap that we use when we create a plot. The following list of colorbars come from [here](https://matplotlib.org/3.1.0/tutorials/colors/colormaps.html). If you are feeling adventerous you can create more yourself.

# %% [markdown]
# ![image](https://matplotlib.org/3.1.0/_images/sphx_glr_colormaps_002.png)
# ![image](https://matplotlib.org/3.1.0/_images/sphx_glr_colormaps_003.png)
# ![image](https://matplotlib.org/3.1.0/_images/sphx_glr_colormaps_004.png)
# ![image](https://matplotlib.org/3.1.0/_images/sphx_glr_colormaps_001.png)

# %% [markdown]
# Let's explore some colormap examples

# %%
#Adding _r at the end, flips the colormap
cmaps = ['RdBu_r','RdPu_r','Greens','binary_r','terrain','viridis']
for cmap in cmaps:
 plt.figure(figsize=(10,10))
 tmp = np.mean(data,axis=0)
 #Pcolormesh is slower but gives you more control
 #We will prefer pcolormesh when we start projecting the data
 plt.pcolormesh(tmp,cmap=plt.get_cmap(cmap))
 plt.axis('off')
 plt.title(cmap,fontsize=25)
 cb = plt.colorbar(orientation='horizontal',shrink=0.8,pad=0.05)
 cb.ax.tick_params(labelsize=15)
 cb.set_label('Monthly temperature ($^o$C)',fontsize=20)
 plt.show()

# %% [markdown]
# * There is so much to learn about matplotlib
# * Your imagination is the limit.
# * Think of what you want to show and the figure out how to do it.
# * Google, tutorials, and these Jupyter Notebooks are your friends.
# * The only way to really learn this is to make plot after plot after plot...
# * You will find all things matplotlib [here](https://matplotlib.org).
