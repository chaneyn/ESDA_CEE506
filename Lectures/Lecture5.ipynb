# %% [markdown]
# # CEE 690-02
#
# # Environmental Spatial Data Analysis
#
# # Lecture 5

# %% [markdown]
#  # Logistics
#
# * All completed HW2 must have been submitted via GitHub at this point.
# * Solutions to Homework 2 will be posted after class.
# * Starting today, we are going to have a 3-5 minute break after the first 40 minutes.

# %% [markdown]
# # Homework #3 (training wheels off!)
#
# <img src="http://4.bp.blogspot.com/-cLWzA4v2zfg/UnpVCk3GQOI/AAAAAAAACBE/JfEyJTi18OI/s1600/training+wheels.jpg" width="500">

# %% [markdown]
# # Data Storage (Input/Output)

# %% [markdown]
# * This problem is one of the largest issues when you go to the TB-PB realm
# * Tradeoff between ease of access and keeping storage costs low
#
# So how do we solve this issue?

# %% [markdown]
# ## Hardware: High perfomance computing (HPC)
#
# Excuse #1: It doesn't matter how poorly I build my database, because I can just use bigger and better storage!
#
# <img src="https://simplecore.intel.com/itpeernetwork/wp-content/uploads/sites/38/2018/09/hpc-ai-servers.jpeg" width="500">

# %% [markdown]
# ## Hardware: Type of storage
#
# Excuse #2: I'll just replace all my storage with faster storage!
#
# <img src="https://www.enterprisestorageforum.com/imagesvr_ce/3985/SSD-vs-HDD.jpg" width="500">

# %% [markdown]
# To be fair, the combination of HPC and SSD do make a large difference.

# %% [markdown]
# ## Software: How we build databases
#
# However, before we buy new hardware, we should optimize the software to reduce the size of our data and to make it very easy to access and manipulate.
#
# And this will be our focus today.
#
# Why? I don't want you to be wasting your time reinventing the wheel on file formats, when there are already very good solutions out there.

# %% [markdown]
# # Outline
#
# * The hard way: Working with text files (e.g., CSV)
# * The easy way: Pickle
# * The best way: NetCDF/HDF5
# * Other ways: (e.g., GeoTIFF)

# %% [markdown]
# # I/O: ASCII files (e.g., CSV)
#
# Let's start by creating a csv file from our ERA-Interim data

# %%
#Define the sites
sites = {'seattle':{'lat':47.6062,'lon':-122.3321},
         'paris':{'lat':48.8566,'lon':2.3522},
         'santiago':{'lat':-33.4489,'lon':-70.6693}}

# %%
import netCDF4 as nc
#Open access to the file
file = '/shared_space/data/era-interim/era_interim_monthly_197901_201512_upscaled.nc'
fp = nc.Dataset(file)
lats = fp['lat'][:]
lons = fp['lon'][:]
times = fp['time']

# %%
import numpy as np
#Look for the closest grid cell center for each site
for site in sites:
    lat = sites[site]['lat']
    lon = sites[site]['lon']
    if lon < 0:lon = 360 + lon
    sites[site]['ilat'] = int(np.argmin(np.abs(lats - lat)))
    sites[site]['ilon'] = int(np.argmin(np.abs(lons - lon)))
print(sites)
# Out:
# {'seattle': {'lat': 47.6062, 'lon': -122.3321, 'ilat': 137, 'ilon': 190}, 'paris': {'lat': 48.8566, 'lon': 2.3522, 'ilat': 138, 'ilon': 1}, 'santiago': {'lat': -33.4489, 'lon': -70.6693, 'ilat': 56, 'ilon': 231}}

# %%
import datetime
#Convert the dates/to a datetime array
dates = nc.num2date(times[:],units=times.units,calendar=times.calendar)

# %%
#Read in multiple variables for each site
vars = {'t2m':'degC','precip':'mm/day','p_sfc':'hPa','wspd10':'m/s'}
for site in sites:
    for var in vars:
        ilat = sites[site]['ilat']
        ilon = sites[site]['ilon']
        sites[site][var] = fp[var][:,ilat,ilon]

# %%
#Let's create a plot of all three sites
# %matplotlib inline
import matplotlib.pyplot as plt
m = dates >= datetime.datetime(2015,1,1)
fig = plt.figure(figsize=(10,10))
for i in range(len(vars.keys())):
    plt.subplot(2,2,i+1)
    for site in sites:
        plt.title('%s (%s)' % (list(vars.keys())[i],vars[list(vars.keys())[i]]),fontsize=25)
        plt.plot(dates[m],sites[site][list(vars.keys())[i]][m],lw=5)
        plt.xticks(rotation=30,fontsize=20)
        plt.yticks(fontsize=20)
    if i == 0:
        plt.legend(list(sites.keys()),fontsize=15)
fig.tight_layout()
plt.show()

# %% [markdown]
# Let's now output the data. We are going to start with the hardest way (and yet the most common...).

# %%
for site in sites:
    print(site)
    #Define the filename to write to
    file = '../Workspace/%s.txt' % site
    #Open the file in write mode
    fp = open(file,'w')
    #Let's add a header
    header = 'date,t2m,precip,p_sfc,wspd10'
    fp.write('%s\n' % header)
    #Now we will iterate through each time step and output the data
    for i in range(dates.size):
        #Convert the timestamp to a date string
        date = dates[i].strftime("%Y/%m")
        #Initialize a list called output with the date string as the first elemetn
        output = [date,]
        #Iterate through all the variables per time step and convert to a string
        #Then append to list
        for var in vars:
            output.append('%.3f' % sites[site][var][i])
        #Join all elements in the list to form one larger string
        string = ",".join(output)
        #Write the string out with an end of line (\n) at the end.
        fp.write('%s\n' % string)
    #Close the file
    fp.close()
# Out:
# seattle
# paris
# santiago

# %% [markdown]
# Let's read all the data back in using the hardest way (again!)

# %%
#Initialize the output dictionary
output = {}
for site in sites:
    print(site)
    if site not in output:output[site] = {'dates':[],'t2m':[],'precip':[],'p_sfc':[],'wspd10':[]}
    #Define the filename to write to
    file = '../Workspace/%s.txt' % site
    #Open the file in read mode
    fp = open(file,'r')
    #Now we will iterate through each line
    for line in fp:
        if 'date' in line:continue #Skip the header
        #Split the line
        tmp = line.split(',')
        #Place the data and convert if necessary
        output[site]['dates'].append(datetime.datetime.strptime(tmp[0],'%Y/%m')) #Convert back to datetime
        output[site]['t2m'].append(float(tmp[1]))
        output[site]['precip'].append(float(tmp[2]))
        output[site]['p_sfc'].append(float(tmp[3]))
        output[site]['wspd10'].append(float(tmp[4]))
    #Close the file
    fp.close()
    #Convert to arrays
    for var in output[site]:
        output[site][var] = np.array(output[site][var])
# Out:
# seattle
# paris
# santiago

# %% [markdown]
# But are we getting the same result?

# %%
i = 0
fig = plt.figure(figsize=(10,10))
for var in vars:
    for site in sites:
        i += 1
        plt.subplot(4,3,i)
        plt.title(site,fontsize=25)
        plt.plot(sites[site][var],output[site][var],'bo')
        plt.plot(sites[site][var],sites[site][var],'k')
        plt.ylabel('%s (%s)' % (var,vars[var]),fontsize=15)
        plt.xticks(rotation=30,fontsize=20)
        plt.yticks(fontsize=20)
fig.tight_layout()
plt.show()

# %% [markdown]
# It that really the best way to read and write spatial data in Python?

# %% [markdown]
# **Definitely not**

# %% [markdown]
# Let's look at other options now

# %% [markdown]
# # ASCII vs Binary
#
# <img src="http://web.alfredstate.edu/faculty/weimandn/miscellaneous/ascii/ASCII%20Conversion%20Chart.gif" width="500">
#
# Reading/writing in ASCII is slower and takes up more space. The storage approaches we will use in this course (except for problem #1 of HW3) use binary.

# %% [markdown]
# # I/O: Pickle
#
# Pickle is part of the Python Standard Library and is the **easiest** (but not always the best) method to read and write data in Python.
#
# <img src="https://www.smartfile.com/blog/wp-content/uploads/2015/11/python-pickle-800x200.png" width="1000">

# %%
import pickle
for site in sites:
    #Define filename
    file = '../Workspace/%s.pck' % site
    #Open the file as writable
    fp = open(file,'wb')
    #Create output database
    output = {'dates':dates,'data':sites[site]}
    pickle.dump(output,fp)
    #Close the file
    fp.close()

# %% [markdown]
# We can even make this easier

# %%
#Define filename
file = '../Workspace/sites.pck'
#Open the file as writable
fp = open(file,'wb')
#Create output database
output = {'dates':dates,'data':sites}
pickle.dump(output,fp)
#Close the file
fp.close()

# %% [markdown]
# Then to read it back in, it is just as simple

# %%
#Define filename
file = '../Workspace/sites.pck'
#Open the file as writable
fp = open(file,'rb')
#Create output database
output = {'dates':dates,'data':sites}
output = pickle.load(fp)
#Close the file
fp.close()

# %% [markdown]
# Same result?

# %%
i = 0
fig = plt.figure(figsize=(10,10))
for var in vars:
    for site in sites:
        i += 1
        plt.subplot(4,3,i)
        plt.title(site,fontsize=25)
        plt.plot(sites[site][var],output['data'][site][var],'bo')
        plt.plot(sites[site][var],sites[site][var],'k')
        plt.ylabel('%s (%s)' % (var,vars[var]),fontsize=15)
        plt.xticks(rotation=30,fontsize=20)
        plt.yticks(fontsize=20)
fig.tight_layout()
plt.show()

# %% [markdown]
# Main point: Using Pickle is much easier than reading and writing text files. It is the go-to method when developing software that involves data in Python.

# %% [markdown]
# However, there are some important issues that limits using Pickle for everything

# %% [markdown]
# Main issues:
#
# * The Pickle file format is exclusive to Python; this makes it difficult to share data with non-Python users
# * The database must be written/read all at once. This can make the I/O process very slow and many times impossible due to computer memory limitations. This is especially a problem for ***Big Data*** (GB+) in environmental spatial data science.
#
# What other alternatives could we use?

# %% [markdown]
# # I/O: netCDF4
#
# <img src="https://www.unidata.ucar.edu/images/logos/netcdf-400x400.png" width="500">

# %% [markdown]
# <img src="https://www.unidata.ucar.edu/software/netcdf/workshops/most-recent/architecture/images/netcdf_history_cropped.png" width="800">
# Note: The following slides are adapted from here: https://www.unidata.ucar.edu/presentations/Rew/netcdf-intro.pdf

# %% [markdown]
# What is **netCDF4**?
#
# * Data model for scientific data
#     * Widely use in Earth and Environmental Sciences
#     * And many other fields as well
# * File format for portable data
#     * Array-oriented data science
#     * Self-describing, portable, and appendable
# * Use in multiple programming languages
#     * C, Java, Fortran, C++, Python, Matlab, IDL,...

# %% [markdown]
# <img src="https://www.unidata.ucar.edu/software/netcdf/docs/nc4-model.png" width="800">

# %% [markdown]
# Let's revisit our I/O example but now in netCDF4

# %%
import netCDF4 as nc

# %%
import os

#Define filename
file = '../Workspace/sites.nc'
os.system('rm -f %s' % file)

#Open the file as writable
fp = nc.Dataset(file,'w')

#Create dimensions
fp.createDimension('time',size=dates.size)

#Write the time data
fp.createVariable('time','i8',dimensions=('time',))
fp['time'].units = 'hours since 0001-01-01 00:00:00.0'
fp['time'].calendar = 'gregorian'
fp['time'][:] = nc.date2num(dates,units=fp['time'].units,calendar=fp['time'].calendar)

#Create a group per site and then add data
for site in sites:
    fp.createGroup(site)
    #Iterate through all the variables and place data
    for var in vars:
        fpv = fp[site].createVariable(var,'f4',dimensions=('time',))
        fpv[:] = sites[site][var]
        
#Close the file
fp.close()

# %% [markdown]
# Let's go to the terminal to list the contents of this new NetCDF4 file.

# %%
# %%bash
# ncdump -h ../Workspace/sites.nc
# Out:
# netcdf sites {
# dimensions:
# 	time = 444 ;
# variables:
# 	int64 time(time) ;
# 		time:units = "hours since 0001-01-01 00:00:00.0" ;
# 		time:calendar = "gregorian" ;
#
# group: seattle {
#   variables:
#   	float t2m(time) ;
#   	float precip(time) ;
#   	float p_sfc(time) ;
#   	float wspd10(time) ;
#   } // group seattle
#
# group: paris {
#   variables:
#   	float t2m(time) ;
#   	float precip(time) ;
#   	float p_sfc(time) ;
#   	float wspd10(time) ;
#   } // group paris
#
# group: santiago {
#   variables:
#   	float t2m(time) ;
#   	float precip(time) ;
#   	float p_sfc(time) ;
#   	float wspd10(time) ;
#   } // group santiago
# }

# %% [markdown]
# The command `ncdump -h` at the terminal does a quick query of a NetCDF4 file.

# %% [markdown]
# Let's now read the data back in to Python

# %%
#Define filename
file = '../Workspace/sites.nc'

#Open the file as readable
fp = nc.Dataset(file,'r')

#Create a group per site and then add data
output = {}
for site in fp.groups:
    print(site)
    output[site] = {}
    #Iterate through all the variables and extract the data
    for var in fp[site].variables:
        output[site][var] = fp[site][var][:]
        
#Close the file
fp.close()
# Out:
# seattle
# paris
# santiago

# %% [markdown]
# Let's check to see if it is the same thing...

# %%
i = 0
fig = plt.figure(figsize=(10,10))
for var in vars:
    for site in sites:
        i += 1
        plt.subplot(4,3,i)
        plt.title(site,fontsize=25)
        plt.plot(sites[site][var],output[site][var],'bo')
        plt.plot(sites[site][var],sites[site][var],'k')
        plt.ylabel('%s (%s)' % (var,vars[var]),fontsize=15)
        plt.xticks(rotation=30,fontsize=20)
        plt.yticks(fontsize=20)
fig.tight_layout()
plt.show()

# %% [markdown]
# <img src="https://www.unidata.ucar.edu/software/netcdf/docs/nc4-model.png" width="700">

# %% [markdown]
# NetCDF4 example: Creating and placing the data

# %%
#data = np.random.randn(500,200,200)
#data = np.random.randint(0,10,(500,200,200))
data = np.zeros((500,200,200))
print(data.shape)
print(np.unique(data))
# Out:
# (500, 200, 200)
# [0.]

# %% [markdown]
# ## Creating the netCDF file

# %%
file = '../Workspace/test.nc'
os.system('rm -f %s' % file)
#Open the file as writable
fp = nc.Dataset(file,'w')

# %% [markdown]
# ## Dimensions in a netCDF file
#
# The netCDF format uses dimensions to define the shapes of variables. Before creating variables, we have to create dimensions.

# %%
#Create dimensions
fp.createDimension('lat',size=data.shape[1])
fp.createDimension('lon',size=data.shape[2])
fp.createDimension('time',size=data.shape[0])
# Out:
# <class 'netCDF4._netCDF4.Dimension'>: name = 'time', size = 500

# %% [markdown]
# ## Variables in a netCDF file

# %%
#Add the data as a variable
fp.createVariable('data','f4',dimensions=('time','lat','lon'))
fp['data'][:] = data[:]

# %% [markdown]
# ## Add some metadata

# %%
fp['data'].units = 'units!'
fp['data'].missing_value = -9999

# %% [markdown]
# ## Close up the file

# %%
fp.close()

# %%
# %%bash
# ncdump -h ../Workspace/test.nc
# du -h ../Workspace/test.nc
# Out:
# netcdf test {
# dimensions:
# 	lat = 200 ;
# 	lon = 200 ;
# 	time = 500 ;
# variables:
# 	float data(time, lat, lon) ;
# 		data :units = "units!" ;
# 		data :missing_value = -9999.f ;
# }
# 77M	../Workspace/test.nc

# %% [markdown]
# ## NetCDF compression: Reduce file size

# %%
file = '../Workspace/test_compressed.nc'
os.system('rm -f %s' % file)
#Open the file as writable
fp = nc.Dataset(file,'w')
#Create dimensions
fp.createDimension('lat',size=data.shape[1])
fp.createDimension('lon',size=data.shape[2])
fp.createDimension('time',size=data.shape[0])
#Add the data as a variable
fp.createVariable('data','f4',dimensions=('time','lat','lon'),zlib=True,least_significant_digit=2)
fp['data'][:] = data[:]
fp['data'].units = 'units!'
fp['data'].missing_value = -9999
fp.close()

# %%
# %%bash
# ncdump -h ../Workspace/test_compressed.nc
# du -h ../Workspace/test_compressed.nc
# Out:
# netcdf test_compressed {
# dimensions:
# 	lat = 200 ;
# 	lon = 200 ;
# 	time = 500 ;
# variables:
# 	float data(time, lat, lon) ;
# 		data :least_significant_digit = 2LL ;
# 		data :units = "units!" ;
# 		data :missing_value = -9999.f ;
# }
# 160K	../Workspace/test_compressed.nc

# %% [markdown]
# We just took a file that was 77 MB and compressed it down to 160 KB. Any idea how? (Hint: it is not magic)

# %% [markdown]
# When we deal with datasets that consist of discrete values, have a lot of missing values, or have lots of 0s (e.g., precipitation), compression makes these data much easier to handle.

# %% [markdown]
# ## NetCDF files: CF convention
#
# The CF convention is a set of common features that spatial data need to have in NetCDF (and other file formats) to ensure that the data can be shared with ease from one place to another.
#
# It tells us how to name variables, what metadata we need to add, what dimensions are appropriate, etc...
#
# http://cfconventions.org/Data/cf-documents/overview/viewgraphs.pdf
#
# I am fully aware that the initial reaction is "who cares?". However, as you work with other data and create your own, using the CF convenction will avoid many, MANY emails to clarify a dataset.

# %% [markdown]
# ## ERA-Interim: Example CF compliant

# %%
# %%bash
# ncdump -h /shared_space/data/era-interim/era_interim_monthly_197901_201512_upscaled.nc
# Out:
# netcdf era_interim_monthly_197901_201512_upscaled {
# dimensions:
# 	time = UNLIMITED ; // (444 currently)
# 	lat = 180 ;
# 	lon = 288 ;
# 	bnds = 2 ;
# variables:
# 	float albedo_sfc(time, lat, lon) ;
# 		albedo_sfc:long_name = "surface albedo" ;
# 		albedo_sfc:_FillValue = -1.e+34f ;
# 		albedo_sfc:missing_value = -1.e+34f ;
# 		albedo_sfc:history = "From /dev/shm/monthly_an_sfc.nc" ;
# 	float blh(time, lat, lon) ;
# 		blh:long_name = "thickness of surface boundary layer" ;
# 		blh:units = "m" ;
# 		blh:_FillValue = -1.e+34f ;
# 		blh:missing_value = -1.e+34f ;
# 		blh:history = "From /dev/shm/monthly_fc_sfc.nc" ;
# 	float cape(time, lat, lon) ;
# 		cape:long_name = "convective available potential energy" ;
# 		cape:units = "J/kg" ;
# 		cape:_FillValue = -1.e+34f ;
# 		cape:missing_value = -1.e+34f ;
# 		cape:history = "From /dev/shm/monthly_fc_sfc.nc" ;
# 	float d2m(time, lat, lon) ;
# 		d2m:long_name = "dewpoint temperature at 2m" ;
# 		d2m:units = "degC" ;
# 		d2m:_FillValue = -1.e+34f ;
# 		d2m:missing_value = -1.e+34f ;
# 		d2m:history = "From /dev/shm/monthly_an_sfc.nc" ;
# 	float evap(time, lat, lon) ;
# 		evap:long_name = "evaporation" ;
# 		evap:units = "mm/day" ;
# 		evap:_FillValue = -1.e+34f ;
# 		evap:missing_value = -1.e+34f ;
# 		evap:history = "From /dev/shm/synoptic_monthly_fc_sfc.nc" ;
# 	float evap_snow(time, lat, lon) ;
# 		evap_snow:long_name = "evaporation of snow water equivalent" ;
# 		evap_snow:units = "mm/day" ;
# 		evap_snow:_FillValue = -1.e+34f ;
# 		evap_snow:missing_value = -1.e+34f ;
# 		evap_snow:history = "From /dev/shm/synoptic_monthly_fc_sfc.nc" ;
# 	float height_sfc(lat, lon) ;
# 		height_sfc:long_name = "geopotential height of surface" ;
# 		height_sfc:units = "m" ;
# 		height_sfc:_FillValue = -1.e+34f ;
# 		height_sfc:missing_value = -1.e+34f ;
# 		height_sfc:history = "From indiv/static.nc" ;
# 	float hi_cld(time, lat, lon) ;
# 		hi_cld:long_name = "high cloud cover" ;
# 		hi_cld:_FillValue = -1.e+34f ;
# 		hi_cld:missing_value = -1.e+34f ;
# 		hi_cld:history = "From /dev/shm/monthly_an_sfc.nc" ;
# 	float land_mask(lat, lon) ;
# 		land_mask:long_name = "land mask" ;
# 		land_mask:_FillValue = -1.e+34f ;
# 		land_mask:missing_value = -1.e+34f ;
# 		land_mask:history = "From indiv/static.nc" ;
# 	float lat(lat) ;
# 		lat:standard_name = "latitude" ;
# 		lat:long_name = "latitude" ;
# 		lat:units = "degrees_north" ;
# 		lat:axis = "Y" ;
# 	float lhflx(time, lat, lon) ;
# 		lhflx:long_name = "surface latent heat flux" ;
# 		lhflx:units = "W/m2" ;
# 		lhflx:_FillValue = -1.e+34f ;
# 		lhflx:missing_value = -1.e+34f ;
# 		lhflx:history = "From /dev/shm/synoptic_monthly_fc_sfc.nc" ;
# 	float lo_cld(time, lat, lon) ;
# 		lo_cld:long_name = "low cloud cover" ;
# 		lo_cld:_FillValue = -1.e+34f ;
# 		lo_cld:missing_value = -1.e+34f ;
# 		lo_cld:history = "From /dev/shm/monthly_an_sfc.nc" ;
# 	float lon(lon) ;
# 		lon:standard_name = "longitude" ;
# 		lon:long_name = "longitude" ;
# 		lon:units = "degrees_east" ;
# 		lon:axis = "X" ;
# 	float lwflx(time, lat, lon) ;
# 		lwflx:long_name = "surface net longwave radiation" ;
# 		lwflx:units = "W/m2" ;
# 		lwflx:_FillValue = -1.e+34f ;
# 		lwflx:missing_value = -1.e+34f ;
# 		lwflx:history = "From /dev/shm/synoptic_monthly_fc_sfc.nc" ;
# 	float lwflx_dn(time, lat, lon) ;
# 		lwflx_dn:long_name = "surface net longwave radiation downward" ;
# 		lwflx_dn:units = "W/m2" ;
# 		lwflx_dn:_FillValue = -1.e+34f ;
# 		lwflx_dn:missing_value = -1.e+34f ;
# 		lwflx_dn:history = "From /dev/shm/synoptic_monthly_fc_sfc.nc" ;
# 	float mid_cld(time, lat, lon) ;
# 		mid_cld:long_name = "middle cloud cover" ;
# 		mid_cld:_FillValue = -1.e+34f ;
# 		mid_cld:missing_value = -1.e+34f ;
# 		mid_cld:history = "From /dev/shm/monthly_an_sfc.nc" ;
# 	float netflx(time, lat, lon) ;
# 		netflx:long_name = "surface net heat flux" ;
# 		netflx:units = "W/m2" ;
# 		netflx:_FillValue = -1.e+34f ;
# 		netflx:missing_value = -1.e+34f ;
# 		netflx:history = "From /dev/shm/synoptic_monthly_fc_sfc.nc" ;
# 	float p_msl(time, lat, lon) ;
# 		p_msl:long_name = "pressure at mean sea level" ;
# 		p_msl:units = "hPa" ;
# 		p_msl:_FillValue = -1.e+34f ;
# 		p_msl:missing_value = -1.e+34f ;
# 		p_msl:history = "From /dev/shm/monthly_an_sfc.nc" ;
# 	float p_sfc(time, lat, lon) ;
# 		p_sfc:long_name = "surface pressure" ;
# 		p_sfc:units = "hPa" ;
# 		p_sfc:_FillValue = -1.e+34f ;
# 		p_sfc:missing_value = -1.e+34f ;
# 		p_sfc:history = "From /dev/shm/monthly_an_sfc.nc" ;
# 	float precip(time, lat, lon) ;
# 		precip:long_name = "precipitation" ;
# 		precip:units = "mm/day" ;
# 		precip:_FillValue = -1.e+34f ;
# 		precip:missing_value = -1.e+34f ;
# 		precip:history = "From /dev/shm/synoptic_monthly_fc_sfc.nc" ;
# 	float precip_conv(time, lat, lon) ;
# 		precip_conv:long_name = "convective precipitation" ;
# 		precip_conv:units = "mm/day" ;
# 		precip_conv:_FillValue = -1.e+34f ;
# 		precip_conv:missing_value = -1.e+34f ;
# 		precip_conv:history = "From /dev/shm/synoptic_monthly_fc_sfc.nc" ;
# 	float precip_ls(time, lat, lon) ;
# 		precip_ls:long_name = "stratiform (large-scale) precipitation" ;
# 		precip_ls:units = "mm/day" ;
# 		precip_ls:_FillValue = -1.e+34f ;
# 		precip_ls:missing_value = -1.e+34f ;
# 		precip_ls:history = "From /dev/shm/synoptic_monthly_fc_sfc.nc" ;
# 	float precip_snow(time, lat, lon) ;
# 		precip_snow:long_name = "snowfall water equivalent" ;
# 		precip_snow:units = "mm/day" ;
# 		precip_snow:_FillValue = -1.e+34f ;
# 		precip_snow:missing_value = -1.e+34f ;
# 		precip_snow:history = "From /dev/shm/synoptic_monthly_fc_sfc.nc" ;
# 	float precip_snow_conv(time, lat, lon) ;
# 		precip_snow_conv:long_name = "convective snowfall water equivalent" ;
# 		precip_snow_conv:units = "mm/day" ;
# 		precip_snow_conv:_FillValue = -1.e+34f ;
# 		precip_snow_conv:missing_value = -1.e+34f ;
# 		precip_snow_conv:history = "From /dev/shm/synoptic_monthly_fc_sfc.nc" ;
# 	float precip_snow_ls(time, lat, lon) ;
# 		precip_snow_ls:long_name = "stratiform (large-scale) snowfall water equivalent" ;
# 		precip_snow_ls:units = "mm/day" ;
# 		precip_snow_ls:_FillValue = -1.e+34f ;
# 		precip_snow_ls:missing_value = -1.e+34f ;
# 		precip_snow_ls:history = "From /dev/shm/synoptic_monthly_fc_sfc.nc" ;
# 	float rh2m(time, lat, lon) ;
# 		rh2m:long_name = "relative humidity at 2m" ;
# 		rh2m:_FillValue = -1.e+34f ;
# 		rh2m:missing_value = -1.e+34f ;
# 		rh2m:history = "From /dev/shm/monthly_an_sfc.nc" ;
# 	float runoff(time, lat, lon) ;
# 		runoff:long_name = "surface water runoff" ;
# 		runoff:units = "mm/day" ;
# 		runoff:_FillValue = -1.e+34f ;
# 		runoff:missing_value = -1.e+34f ;
# 		runoff:history = "From /dev/shm/synoptic_monthly_fc_sfc.nc" ;
# 	float shflx(time, lat, lon) ;
# 		shflx:long_name = "surface sensible heat flux" ;
# 		shflx:units = "W/m2" ;
# 		shflx:_FillValue = -1.e+34f ;
# 		shflx:missing_value = -1.e+34f ;
# 		shflx:history = "From /dev/shm/synoptic_monthly_fc_sfc.nc" ;
# 	float swflx(time, lat, lon) ;
# 		swflx:long_name = "surface net shortwave radiation" ;
# 		swflx:units = "W/m2" ;
# 		swflx:_FillValue = -1.e+34f ;
# 		swflx:missing_value = -1.e+34f ;
# 		swflx:history = "From /dev/shm/synoptic_monthly_fc_sfc.nc" ;
# 	float swflx_dn(time, lat, lon) ;
# 		swflx_dn:long_name = "surface net shortwave radiation downward" ;
# 		swflx_dn:units = "W/m2" ;
# 		swflx_dn:_FillValue = -1.e+34f ;
# 		swflx_dn:missing_value = -1.e+34f ;
# 		swflx_dn:history = "From /dev/shm/synoptic_monthly_fc_sfc.nc" ;
# 	float t2m(time, lat, lon) ;
# 		t2m:long_name = "temperature at 2m" ;
# 		t2m:units = "degC" ;
# 		t2m:_FillValue = -1.e+34f ;
# 		t2m:missing_value = -1.e+34f ;
# 		t2m:history = "From /dev/shm/monthly_an_sfc.nc" ;
# 	float t_skin(time, lat, lon) ;
# 		t_skin:long_name = "skin temperature" ;
# 		t_skin:units = "degC" ;
# 		t_skin:_FillValue = -1.e+34f ;
# 		t_skin:missing_value = -1.e+34f ;
# 		t_skin:history = "From /dev/shm/monthly_an_sfc.nc" ;
# 	float tau_x(time, lat, lon) ;
# 		tau_x:long_name = "surface zonal wind stress" ;
# 		tau_x:units = "dPa" ;
# 		tau_x:_FillValue = -1.e+34f ;
# 		tau_x:missing_value = -1.e+34f ;
# 		tau_x:history = "From /dev/shm/synoptic_monthly_fc_sfc.nc" ;
# 	float tau_y(time, lat, lon) ;
# 		tau_y:long_name = "surface meridional wind stress" ;
# 		tau_y:units = "dPa" ;
# 		tau_y:_FillValue = -1.e+34f ;
# 		tau_y:missing_value = -1.e+34f ;
# 		tau_y:history = "From /dev/shm/synoptic_monthly_fc_sfc.nc" ;
# 	float tciw(time, lat, lon) ;
# 		tciw:long_name = "total column ice water" ;
# 		tciw:units = "kg/m2" ;
# 		tciw:_FillValue = -1.e+34f ;
# 		tciw:missing_value = -1.e+34f ;
# 		tciw:history = "From /dev/shm/monthly_fc_sfc.nc" ;
# 	float tclw(time, lat, lon) ;
# 		tclw:long_name = "total column liquid water" ;
# 		tclw:units = "kg/m2" ;
# 		tclw:_FillValue = -1.e+34f ;
# 		tclw:missing_value = -1.e+34f ;
# 		tclw:history = "From /dev/shm/monthly_fc_sfc.nc" ;
# 	float tcw(time, lat, lon) ;
# 		tcw:long_name = "total column water" ;
# 		tcw:units = "kg/m2" ;
# 		tcw:_FillValue = -1.e+34f ;
# 		tcw:missing_value = -1.e+34f ;
# 		tcw:history = "From /dev/shm/monthly_an_sfc.nc" ;
# 	float tcwv(time, lat, lon) ;
# 		tcwv:long_name = "total column water vapor" ;
# 		tcwv:units = "kg/m2" ;
# 		tcwv:_FillValue = -1.e+34f ;
# 		tcwv:missing_value = -1.e+34f ;
# 		tcwv:history = "From /dev/shm/monthly_an_sfc.nc" ;
# 	double time(time) ;
# 		time:standard_name = "time" ;
# 		time:long_name = "time" ;
# 		time:bounds = "time_bnds" ;
# 		time:units = "days since 1979-01-01 00:00:00" ;
# 		time:calendar = "standard" ;
# 		time:axis = "T" ;
# 	double time_bnds(time, bnds) ;
# 	float tot_cld(time, lat, lon) ;
# 		tot_cld:long_name = "total cloud cover" ;
# 		tot_cld:_FillValue = -1.e+34f ;
# 		tot_cld:missing_value = -1.e+34f ;
# 		tot_cld:history = "From /dev/shm/monthly_an_sfc.nc" ;
# 	float wspd10(time, lat, lon) ;
# 		wspd10:long_name = "wind speed at 10m" ;
# 		wspd10:units = "m/s" ;
# 		wspd10:_FillValue = -1.e+34f ;
# 		wspd10:missing_value = -1.e+34f ;
# 		wspd10:history = "From /dev/shm/monthly_an_sfc.nc" ;
#
# // global attributes:
# 		:CDI = "Climate Data Interface version 1.8.2 (http://mpimet.mpg.de/cdi)" ;
# 		:Conventions = "CF-1.6" ;
# 		:history = "Tue Dec  4 14:47:10 2018: ncks -x -v lwflx_toa_clr,lwflx_toa,swflx_toa_clr,swflx_toa_dn,swflx_toa,netflx_toa,lwflx_clr,swflx_clr,tco3,sea_ice,skin_water,snow_water,charnock,v10,u10,sst tmp.nc era_interim_monthly_197901_201512_upscaled.nc\n",
# 			"Tue Dec 04 14:39:21 2018: cdo remapcon,grid.cdo era_interim_monthly_197901_201512.nc tmp.nc\n",
# 			"FERRET V7.01 (beta/optim) 29-Sep-16" ;
# 		:title = "ERA-Interim" ;
# 		:CDO = "Climate Data Operators version 1.8.2 (http://mpimet.mpg.de/cdo)" ;
# 		:NCO = "\"4.6.4\"" ;
# }

# %% [markdown]
# Want more specifics on what being CF compliant using NetCDF entails?
#
# Go here: http://cfconventions.org/Data/cf-conventions/cf-conventions-1.7/cf-conventions.html#_netcdf_files_and_components

# %% [markdown]
# # I/O: HDF5
#
# <img src="https://www.hdfgroup.org/wp-content/uploads/2017/06/benefits-wheel.png" width="500">

# %% [markdown]
# NetCDF4 is actually built on HDF5. Although we tend to use NetCDF4 for consistency, native HDF5 is faster and can be much more flexible. Unless I am aiming to share my data with the wider scientific community, I almost always only use native HDF5.

# %% [markdown]
# <img src="https://image.slidesharecdn.com/rewnethdf-short-140220112557-phpapp01/95/plans-for-enhanced-netcdf4-interface-to-hdf5-data-6-638.jpg?cb=1392895997" width="600">

# %%
import h5py
file = '../Workspace/sites.h5'

#Open the file as writable
fp = h5py.File(file,'w')

#Iterate per variable
for site in sites:
    fp.create_group(site)
    for var in vars:
        fp[site][var] = sites[site][var][:]
    
#Close the file
fp.close()

# %%
# %%bash
#
# h5dump -n ../Workspace/sites.h5
# Out:
# HDF5 "../Workspace/sites.h5" {
# FILE_CONTENTS {
#  group      /
#  group      /paris
#  dataset    /paris/p_sfc
#  dataset    /paris/precip
#  dataset    /paris/t2m
#  dataset    /paris/wspd10
#  group      /santiago
#  dataset    /santiago/p_sfc
#  dataset    /santiago/precip
#  dataset    /santiago/t2m
#  dataset    /santiago/wspd10
#  group      /seattle
#  dataset    /seattle/p_sfc
#  dataset    /seattle/precip
#  dataset    /seattle/t2m
#  dataset    /seattle/wspd10
#  }
# }

# %% [markdown]
# Here we use `h5dump -n` at the terminal instead of `ncdump -h`. It is the exact same idea though.

# %% [markdown]
# Let's quickly prove that NetCDF4 is HDF5 by trying to read it as NetCDF4.

# %%
# %%bash
#
# ncdump -h ../Workspace/sites.h5
# Out:
# netcdf sites {
#
# group: paris {
#   dimensions:
#   	phony_dim_0 = 444 ;
#   variables:
#   	float p_sfc(phony_dim_0) ;
#   	float precip(phony_dim_0) ;
#   	float t2m(phony_dim_0) ;
#   	float wspd10(phony_dim_0) ;
#   } // group paris
#
# group: santiago {
#   dimensions:
#   	phony_dim_1 = 444 ;
#   variables:
#   	float p_sfc(phony_dim_1) ;
#   	float precip(phony_dim_1) ;
#   	float t2m(phony_dim_1) ;
#   	float wspd10(phony_dim_1) ;
#   } // group santiago
#
# group: seattle {
#   dimensions:
#   	phony_dim_2 = 444 ;
#   variables:
#   	float p_sfc(phony_dim_2) ;
#   	float precip(phony_dim_2) ;
#   	float t2m(phony_dim_2) ;
#   	float wspd10(phony_dim_2) ;
#   } // group seattle
# }

# %% [markdown]
# The main difference between NetCDF4 and HDF5 is that in NetCDF4 we have to specify dimensions while in HDF5 they are implicit unless we specify them. But yes, one can create a NetCDF4 file using h5py (or any HDF5 library).

# %% [markdown]
# # I/O: Raster data
#
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/3/3b/Rgb-raster-image.svg/368px-Rgb-raster-image.svg.png" width="200">
#
# Raster: A raster image is a data structure that represents a spatial grid of pixels. In other words, it's a 2D array. One tends to only think of rasters when thinking of 2D arrays with only lat and lon axes. N-dimensional arrays are a generalization of raster data.
#
# However, this word will emerge many times so better to not be confused!

# %% [markdown]
# ## Raster data file formats
#
# It seems that creating raster file formats used to be a hobby...
#
# [Raster formats](https://gdal.org/drivers/raster/index.html)
#
# Thankfully things have calmed down (kind of).
#
# NetCDF and HDF5 are considered to be "raster formats". Although to be compliant it causes many restrictions on using file formats.

# %% [markdown]
# ## GeoTIFF: Most common raster format

# %%
# %%bash
# gdalinfo /shared_space/data/NED/dem_lat3940_lon-93-92.tif
# Out:
# Driver: GTiff/GeoTIFF
# Files: /shared_space/data/NED/dem_lat3940_lon-93-92.tif
# Size is 3600, 3600
# Coordinate System is:
# GEOGCS["WGS 84",
#     DATUM["WGS_1984",
#         SPHEROID["WGS 84",6378137,298.257223563,
#             AUTHORITY["EPSG","7030"]],
#         AUTHORITY["EPSG","6326"]],
#     PRIMEM["Greenwich",0],
#     UNIT["degree",0.0174532925199433],
#     AUTHORITY["EPSG","4326"]]
# Origin = (-93.000000000000000,40.000000000000000)
# Pixel Size = (0.000277777777778,-0.000277777777778)
# Metadata:
#   AREA_OR_POINT=Area
# Image Structure Metadata:
#   INTERLEAVE=BAND
# Corner Coordinates:
# Upper Left  ( -93.0000000,  40.0000000) ( 93d 0' 0.00"W, 40d 0' 0.00"N)
# Lower Left  ( -93.0000000,  39.0000000) ( 93d 0' 0.00"W, 39d 0' 0.00"N)
# Upper Right ( -92.0000000,  40.0000000) ( 92d 0' 0.00"W, 40d 0' 0.00"N)
# Lower Right ( -92.0000000,  39.0000000) ( 92d 0' 0.00"W, 39d 0' 0.00"N)
# Center      ( -92.5000000,  39.5000000) ( 92d30' 0.00"W, 39d30' 0.00"N)
# Band 1 Block=3600x1 Type=Float32, ColorInterp=Gray
#   NoData Value=-99999
# pj_obj_create: Open of /opt/conda/share/proj failed

# %% [markdown]
# ## Reading raster data in Python?
#
# There are many options. I use rasterio.

# %%
import rasterio

# %%
file = '/shared_space/data/NED/dem_lat3940_lon-93-92.tif'
#Open up access to the file
fp = rasterio.open(file)
#Read the first band (each time step would be a different band in a 3d array of time/lat/lon)
dem = fp.read(1)

# %%
#Make a quick plot
plt.figure(figsize=(20,20))
plt.imshow(dem,cmap=plt.get_cmap('terrain'))
plt.axis('off')
plt.show()

# %% [markdown]
# If we look closer at the file pointer opened by Rasterio we can learn a lot about the data

# %%
dir(fp)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__enter__',
#  '__eq__',
#  '__exit__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__pyx_vtable__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_block_shapes',
#  '_closed',
#  '_count',
#  '_crs',
#  '_crs_wkt',
#  '_descriptions',
#  '_dtypes',
#  '_env',
#  '_gcps',
#  '_get_crs',
#  '_handle_crswkt',
#  '_has_band',
#  '_mask_flags',
#  '_nodatavals',
#  '_offsets',
#  '_read',
#  '_scales',
#  '_set_all_descriptions',
#  '_set_all_offsets',
#  '_set_all_scales',
#  '_set_all_units',
#  '_set_attrs_from_dataset_handle',
#  '_set_crs',
#  '_set_gcps',
#  '_set_nodatavals',
#  '_transform',
#  '_units',
#  'block_shapes',
#  'block_size',
#  'block_window',
#  'block_windows',
#  'bounds',
#  'checksum',
#  'close',
#  'closed',
#  'colorinterp',
#  'colormap',
#  'compression',
#  'count',
#  'crs',
#  'dataset_mask',
#  'descriptions',
#  'driver',
#  'dtypes',
#  'files',
#  'gcps',
#  'get_gcps',
#  'get_nodatavals',
#  'get_tag_item',
#  'get_transform',
#  'height',
#  'index',
#  'indexes',
#  'interleaving',
#  'is_tiled',
#  'lnglat',
#  'mask_flag_enums',
#  'meta',
#  'mode',
#  'name',
#  'nodata',
#  'nodatavals',
#  'offsets',
#  'options',
#  'overviews',
#  'photometric',
#  'profile',
#  'read',
#  'read_crs',
#  'read_masks',
#  'read_transform',
#  'res',
#  'sample',
#  'scales',
#  'shape',
#  'stop',
#  'subdatasets',
#  'tags',
#  'transform',
#  'units',
#  'width',
#  'window',
#  'window_bounds',
#  'window_transform',
#  'write_transform',
#  'xy']

# %% [markdown]
# We can directly determine the shape of the array (i.e., raster) before reading it in.

# %%
print(fp.width)
print(fp.height)
# Out:
# 3600
# 3600

# %% [markdown]
# We can extract the boundaries of the data. This example is in lat/lon.

# %%
print(fp.bounds)
# Out:
# BoundingBox(left=-93.0, bottom=38.99999999999992, right=-91.99999999999991, top=40.0)

# %% [markdown]
# It also tells us the map projection of the data

# %%
print(fp._crs)
# Out:
# EPSG:4326

# %% [markdown]
# There is a lot to learn about map projections (and we will). But we are going to set that aside for now and spend some time actually using all the methods/tools that we have learned over the past few weeks.
